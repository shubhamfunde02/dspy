# %% [markdown]
# # Experiment No.8

# %% [markdown]
# ## 1. What is 2 tailed and tailed T Test?

# %% [markdown]
# ###  A one-tailed t-test is used when we want to test if a parameter (like the mean) is either greater than or less than a specific value in a single direction. For example, testing whether the average score is greater than 50.).ce

# %% [markdown]
# ## 2. Explain what is Type I and Type II errors with an example.

# %% [markdown]
# ### Start → State H₀ & H₁ → Choose α → Select test (z/t) → Collect data → Compute statistic → Compare (critical value / p-value) → Decision (Reject / Accept H₀) ke Decision
