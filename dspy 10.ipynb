# %% [markdown]
# # Experiment No.10

# %% [markdown]
# ## 1. When do we go for Chi square test ?

# %% [markdown]
# ### The Chi-square test is used when we are working with categorical data and want to examine relationships or differences between variables. It is commonly used in situations like testing frequencies, proportions, or distributions across categories.).ce

# %% [markdown]
# ## 2. Do we use Chi square test for independence ? Explain How ?

# %% [markdown]
# ### Yes, the Chi-square test of independence is used to check whether two categorical variables are independent or related.:
#
# We create a contingency table of observed frequencies.
# We calculate expected frequencies assuming variables are independent.
# We compute the Chi-square statistic using the formula:
# χ² = Σ (Observed − Expected)² / Expected
# We compare the result with a critical value or use the p-value.do.ke Decision

# %% [markdown]
# ## 3. Explain role of Critical value and p-value in Chi square test.

# %% [markdown]
# ### The power of a statistical test is the probability that the test correctly rejects a false null hypothesis. In simple terms, it measures how likely the test is to detect a real effect when it actually exists. Power = 1 − (probability of Type II error). Higher power means a better chance of detecting true differences.
